# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans

# %%
iris = load_iris().data

# %%
kmeans = KMeans(n_clusters=3)

# %%
kmeans.fit(iris)
labels = kmeans.labels_
# Out:
# /home/misha/Python/magistr/env/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
count1 = 0
count2 = 0
count3 = 0

for i in range(len(iris)):
    if labels[i] == 0:
        print("Ирис {} принадлежит к кластеру 1".format(i))
        count1 += 1
    elif labels[i] == 1:
        print("Ирис {} принадлежит к кластеру 2".format(i))
        count2 += 1
    else:
        print("Ирис {} принадлежит к кластеру 3".format(i))
        count3 += 1

print(count1)
print(count2)
print(count3)
# Out:
# Ирис 0 принадлежит к кластеру 2
# Ирис 1 принадлежит к кластеру 2
# Ирис 2 принадлежит к кластеру 2
# Ирис 3 принадлежит к кластеру 2
# Ирис 4 принадлежит к кластеру 2
# Ирис 5 принадлежит к кластеру 2
# Ирис 6 принадлежит к кластеру 2
# Ирис 7 принадлежит к кластеру 2
# Ирис 8 принадлежит к кластеру 2
# Ирис 9 принадлежит к кластеру 2
# Ирис 10 принадлежит к кластеру 2
# Ирис 11 принадлежит к кластеру 2
# Ирис 12 принадлежит к кластеру 2
# Ирис 13 принадлежит к кластеру 2
# Ирис 14 принадлежит к кластеру 2
# Ирис 15 принадлежит к кластеру 2
# Ирис 16 принадлежит к кластеру 2
# Ирис 17 принадлежит к кластеру 2
# Ирис 18 принадлежит к кластеру 2
# Ирис 19 принадлежит к кластеру 2
# Ирис 20 принадлежит к кластеру 2
# Ирис 21 принадлежит к кластеру 2
# Ирис 22 принадлежит к кластеру 2
# Ирис 23 принадлежит к кластеру 2
# Ирис 24 принадлежит к кластеру 2
# Ирис 25 принадлежит к кластеру 2
# Ирис 26 принадлежит к кластеру 2
# Ирис 27 принадлежит к кластеру 2
# Ирис 28 принадлежит к кластеру 2
# Ирис 29 принадлежит к кластеру 2
# Ирис 30 принадлежит к кластеру 2
# Ирис 31 принадлежит к кластеру 2
# Ирис 32 принадлежит к кластеру 2
# Ирис 33 принадлежит к кластеру 2
# Ирис 34 принадлежит к кластеру 2
# Ирис 35 принадлежит к кластеру 2
# Ирис 36 принадлежит к кластеру 2
# Ирис 37 принадлежит к кластеру 2
# Ирис 38 принадлежит к кластеру 2
# Ирис 39 принадлежит к кластеру 2
# Ирис 40 принадлежит к кластеру 2
# Ирис 41 принадлежит к кластеру 2
# Ирис 42 принадлежит к кластеру 2
# Ирис 43 принадлежит к кластеру 2
# Ирис 44 принадлежит к кластеру 2
# Ирис 45 принадлежит к кластеру 2
# Ирис 46 принадлежит к кластеру 2
# Ирис 47 принадлежит к кластеру 2
# Ирис 48 принадлежит к кластеру 2
# Ирис 49 принадлежит к кластеру 2
# Ирис 50 принадлежит к кластеру 3
# Ирис 51 принадлежит к кластеру 3
# Ирис 52 принадлежит к кластеру 1
# Ирис 53 принадлежит к кластеру 3
# Ирис 54 принадлежит к кластеру 3
# Ирис 55 принадлежит к кластеру 3
# Ирис 56 принадлежит к кластеру 3
# Ирис 57 принадлежит к кластеру 3
# Ирис 58 принадлежит к кластеру 3
# Ирис 59 принадлежит к кластеру 3
# Ирис 60 принадлежит к кластеру 3
# Ирис 61 принадлежит к кластеру 3
# Ирис 62 принадлежит к кластеру 3
# Ирис 63 принадлежит к кластеру 3
# Ирис 64 принадлежит к кластеру 3
# Ирис 65 принадлежит к кластеру 3
# Ирис 66 принадлежит к кластеру 3
# Ирис 67 принадлежит к кластеру 3
# Ирис 68 принадлежит к кластеру 3
# Ирис 69 принадлежит к кластеру 3
# Ирис 70 принадлежит к кластеру 3
# Ирис 71 принадлежит к кластеру 3
# Ирис 72 принадлежит к кластеру 3
# Ирис 73 принадлежит к кластеру 3
# Ирис 74 принадлежит к кластеру 3
# Ирис 75 принадлежит к кластеру 3
# Ирис 76 принадлежит к кластеру 3
# Ирис 77 принадлежит к кластеру 1
# Ирис 78 принадлежит к кластеру 3
# Ирис 79 принадлежит к кластеру 3
# Ирис 80 принадлежит к кластеру 3
# Ирис 81 принадлежит к кластеру 3
# Ирис 82 принадлежит к кластеру 3
# Ирис 83 принадлежит к кластеру 3
# Ирис 84 принадлежит к кластеру 3
# Ирис 85 принадлежит к кластеру 3
# Ирис 86 принадлежит к кластеру 3
# Ирис 87 принадлежит к кластеру 3
# Ирис 88 принадлежит к кластеру 3
# Ирис 89 принадлежит к кластеру 3
# Ирис 90 принадлежит к кластеру 3
# Ирис 91 принадлежит к кластеру 3
# Ирис 92 принадлежит к кластеру 3
# Ирис 93 принадлежит к кластеру 3
# Ирис 94 принадлежит к кластеру 3
# Ирис 95 принадлежит к кластеру 3
# Ирис 96 принадлежит к кластеру 3
# Ирис 97 принадлежит к кластеру 3
# Ирис 98 принадлежит к кластеру 3
# Ирис 99 принадлежит к кластеру 3
# Ирис 100 принадлежит к кластеру 1
# Ирис 101 принадлежит к кластеру 3
# Ирис 102 принадлежит к кластеру 1
# Ирис 103 принадлежит к кластеру 1
# Ирис 104 принадлежит к кластеру 1
# Ирис 105 принадлежит к кластеру 1
# Ирис 106 принадлежит к кластеру 3
# Ирис 107 принадлежит к кластеру 1
# Ирис 108 принадлежит к кластеру 1
# Ирис 109 принадлежит к кластеру 1
# Ирис 110 принадлежит к кластеру 1
# Ирис 111 принадлежит к кластеру 1
# Ирис 112 принадлежит к кластеру 1
# Ирис 113 принадлежит к кластеру 3
# Ирис 114 принадлежит к кластеру 3
# Ирис 115 принадлежит к кластеру 1
# Ирис 116 принадлежит к кластеру 1
# Ирис 117 принадлежит к кластеру 1
# Ирис 118 принадлежит к кластеру 1
# Ирис 119 принадлежит к кластеру 3
# Ирис 120 принадлежит к кластеру 1
# Ирис 121 принадлежит к кластеру 3
# Ирис 122 принадлежит к кластеру 1
# Ирис 123 принадлежит к кластеру 3
# Ирис 124 принадлежит к кластеру 1
# Ирис 125 принадлежит к кластеру 1
# Ирис 126 принадлежит к кластеру 3
# Ирис 127 принадлежит к кластеру 3
# Ирис 128 принадлежит к кластеру 1
# Ирис 129 принадлежит к кластеру 1
# Ирис 130 принадлежит к кластеру 1
# Ирис 131 принадлежит к кластеру 1
# Ирис 132 принадлежит к кластеру 1
# Ирис 133 принадлежит к кластеру 3
# Ирис 134 принадлежит к кластеру 1
# Ирис 135 принадлежит к кластеру 1
# Ирис 136 принадлежит к кластеру 1
# Ирис 137 принадлежит к кластеру 1
# Ирис 138 принадлежит к кластеру 3
# Ирис 139 принадлежит к кластеру 1
# Ирис 140 принадлежит к кластеру 1
# Ирис 141 принадлежит к кластеру 1
# Ирис 142 принадлежит к кластеру 3
# Ирис 143 принадлежит к кластеру 1
# Ирис 144 принадлежит к кластеру 1
# Ирис 145 принадлежит к кластеру 1
# Ирис 146 принадлежит к кластеру 3
# Ирис 147 принадлежит к кластеру 1
# Ирис 148 принадлежит к кластеру 1
# Ирис 149 принадлежит к кластеру 3
# 38
# 50
# 62
